# %%
#data loading
import os 
dir_path = os.getcwd()+"/idebate.json"
dir_path
# Out:
# '/Users/yutian/Downloads/NEU/NLP/project/repository/idebate.json'

# %%
from __future__ import division, absolute_import, print_function

from six.moves import urllib, xrange

import tensorflow as tf
import numpy as np
import collections, math, os, random, zipfile
# Out:
# /Users/yutian/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
import json
json_data=open(dir_path).read()
data = json.loads(json_data)
text=""
for i in data:
    for index in i['_argument_sentences']:
        text=text+i['_argument_sentences'][index]

# %%
words = tf.compat.as_str(text).split()

# %%
vocabulary_size = 20000
def build_dataset(words):
    # create counts list, set counts for "UNK" token to -1 (undefined)
    count = [['UNK', -1]]
    # add counts of the 49,999 most common tokens in 'words'
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    # create the dictionary data structure
    dictionary = {}
    # give a unique integer ID to each token in the dictionary
    for word, _ in count:
        dictionary[word] = len(dictionary)
    # create a list data structure for the data
    data = []
    # keep track of the number of "UNK" token occurrences
    unk_count = 0
    # for each word in our list of words
    for word in words:
        # if its in the dictionary, get its index
        if word in dictionary:
            index = dictionary[word]
        # otherwise, set the index equal to zero (index of "UNK") and increment the "UNK" count
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        # append its index to the 'data' list structure
        data.append(index)
    # set the count of "UNK" in the 'count' data structure
    count[0][1] = unk_count
    # invert the dictionary; it becomes (index, word) key-value pairs
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    # return the data (indices), counts, dictionary, and inverted dictionary
    return data, count, dictionary, reverse_dictionary

# build the datset
data, count, dictionary, reverse_dictionary = build_dataset(words)
# free up some memory
del words
# print out stats
print('most common words (+UNK):', count[:10])
print('sample data:', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# most common words (+UNK): [['UNK', 6289], ('the', 20926), (',', 18382), ('to', 13803), ('of', 13348), ('and', 10269), ('a', 7750), ('in', 7747), ('is', 6353), ('that', 5177)]
# sample data: [13573, 2, 5298, 2, 2, 9868, 1222, 2, 186, 2] ['Skolnik', ',', 'Sam', ',', ',', 'Beacon', 'Press', ',', '2011', ',']

# %%
len(reverse_dictionary)
# Out:
# 20000

# %%
data_index = 0

# generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    # make sure our parameters are self-consistent
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    # create empty batch ndarray using 'batch_size'
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    # create empty labels ndarray using 'batch_size'
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # [ skip_window target skip_window ]
    span = 2 * skip_window + 1
    # create a buffer object for prepping batch data
    buffer = collections.deque(maxlen=span)
    # for each element in our calculated span, append the datum at 'data_index' and increment 'data_index' moduli the amount of data
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # loop for 'batch_size' // 'num_skips'
    for i in range(batch_size // num_skips):
         # target label at the center of the buffer
        target = skip_window
        targets_to_avoid = [skip_window]
        # loop for 'num_skips'
        for j in range(num_skips):
            # loop through all 'targets_to_avoid'
            while target in targets_to_avoid:
                # pick a random index as target
                target = random.randint(0, span - 1)
            # put it in 'targets_to_avoid'
            targets_to_avoid.append(target)
            # set the skip window in the minibatch data
            batch[i * num_skips + j] = buffer[skip_window]
            # set the target in the minibatch labels
            labels[i * num_skips + j, 0] = buffer[target]
        # add the data at the current 'data_index' to the buffer
        buffer.append(data[data_index])
        # increment 'data_index'
        data_index = (data_index + 1) % len(data)
    # return the minibatch data and corresponding labels
    return batch, labels

# get a minibatch
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

# print out part of the minibatch to the console
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 2 , -> 5298 Sam
# 2 , -> 13573 Skolnik
# 5298 Sam -> 2 ,
# 5298 Sam -> 2 ,
# 2 , -> 2 ,
# 2 , -> 5298 Sam
# 2 , -> 9868 Beacon
# 2 , -> 2 ,

# %%
# hyperparameters
batch_size = 128
embedding_size = 128 # dimension of the embedding vector
skip_window = 1 # how many words to consider to left and right
num_skips = 2 # how many times to reuse an input to generate a label

# we choose random validation dataset to sample nearest neighbors
# here, we limit the validation samples to the words that have a low
# numeric ID, which are also the most frequently occurring words
valid_size = 16 # size of random set of words to evaluate similarity on
valid_window = 100 # only pick development samples from the first 'valid_window' words
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64 # number of negative examples to sample

# create computation graph
graph = tf.Graph()

with graph.as_default():
    # input data
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # operations and variables
    # look up embeddings for inputs
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # construct the variables for the NCE loss
    nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each time we evaluate the loss.
    loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights, biases=nce_biases,labels=train_labels, inputs=embed, num_sampled=num_sampled, num_classes=vocabulary_size))
    
    # construct the SGD optimizer using a learning rate of 1.0
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # compute the cosine similarity between minibatch examples and all embeddings
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

    # add variable initializer
    init = tf.global_variables_initializer()

# %%
# steps to train the model
num_steps = 50001

with tf.Session(graph=graph) as session:
    # we must initialize all variables before using them
    init.run()
    print('initialized.')
    
    # loop through all training steps and keep track of loss
    average_loss = 0
    for step in xrange(num_steps):
        # generate a minibatch of training data
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}
        
        # we perform a single update step by evaluating the optimizer operation (including it
        # in the list of returned values of session.run())
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
        
        # print average loss every 2,000 steps
        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # the average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0
        
        # computing cosine similarity (expensive!)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                # get a single validation sample
                valid_word = reverse_dictionary[valid_examples[i]]
                # number of nearest neighbors
                top_k = 8
                # computing nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
        
    final_embeddings = normalized_embeddings.eval()
# Out:
# initialized.
# Average loss at step  0 :  251.38999939
# nearest to into: .Offshoring, investment, discourses, al-Shabaab, .American, security, sister, blasts,
# nearest to rights: businesss, market, Wagener, censoring, Ornstein, U.S.-based, dated, featured,
# nearest to is: Matters, .Washington, theatrical, wind, Harvard, disapproval, elect, cared,
# nearest to when: prompting, altitude, prepares, .British, undermined, fingers, pattern, comprehension,
# nearest to should: injustices, Behind, .Due, anti-tank, real, 2013The, futures, vegetative,
# nearest to with: Denkinger, .Tax, transcended, gambling, tabloids, 125mph, factual, whychurch.org.uk,
# nearest to own: penalties, hardly, swiftly, .Having, fumbling, varieties, efficiency, uniformly,
# nearest to was: India, siege, unemployable, .1973, .Allowing, inviolability, Unlike, omission,
# nearest to countries: 1,000, territorial, disseminates, list, rapprochement, 1-2, 2013European, .Minority,
# nearest to one: inhabited, RAND, powers, profligate, ambiguities, board, feasibly, .GERD,
# nearest to more: Rey, eliminated, Villiers, 6627, 25s, depicting, Laden, oversight,
# nearest to example: jail, carpenter, Chiefs, contrast, scores, array, healings, propensity,
# nearest to its: .Doubt, endorsement, 2004, boringbaseball, Kill, Realschule, .Merkel, multi-tracking,
# nearest to make: laid, Zoo, attempted, constitute, Codevilla, ,Arming, did, audiences,
# nearest to no: two, kidneys, taking, volunteering, .Kennedy, Planet, Epps, tyrannical,
# nearest to any: summoned, prolonging, Christensen, 1995, railroad, obstructed, so, trend,
# Average loss at step  2000 :  72.4895584655
# Average loss at step  4000 :  21.5435808449
# Average loss at step  6000 :  10.4266223698
# Average loss at step  8000 :  7.89021337223
# Average loss at step  10000 :  6.23560815907
# nearest to into: investment, .Offshoring, and, .American, in, security, shown, al-Shabaab,
# nearest to rights: businesss, market, 32, Wagener, Morocco, German, perpetrators, field,
# nearest to is: was, has, minimize, are, be, play, facts, worries,
# nearest to when: differences, prompting, undermined, shouldnt, serve, altitude, .If, pattern,
# nearest to should: can, would, may, will, occurs, rallies, carried, tend,
# nearest to with: for, in, basis, religion, transcended, Denkinger, gambling, to,
# nearest to own: swiftly, varieties, penalties, .Having, 2050, hardly, efficiency, remittances,
# nearest to was: is, in, C.I.A., are, India, pre-1967, direction, unemployable,
# nearest to countries: territorial, rapprochement, list, drugs, .Castration, helping, tested, 1-2,
# nearest to one: powers, board, choose, profligate, 6, .States, RAND, specifically,
# nearest to more: eliminated, reduce, depicting, decile, referendums, talent, intergovernmental, benefit,
# nearest to example: jail, contrast, smoking, forward, miniature, contributions, array, scores,
# nearest to its: the, .Doubt, endorsement, their, themselves, 2004, secretary, severity,
# nearest to make: did, constitute, attempted, laid, all-time, audiences, interpretation, ,Arming,
# nearest to no: aimed, a, Oslo, 1998, .China, parties, Cambodia, two,
# nearest to any: 1995, summoned, so, measures, Jim, restructuring, wars, trend,
# Average loss at step  12000 :  5.0852514894
# Average loss at step  14000 :  5.09870708179
# Average loss at step  16000 :  4.92995809603
# Average loss at step  18000 :  4.63831327868
# Average loss at step  20000 :  4.63050685084
# nearest to into: .Offshoring, in, al-Shabaab, stab, .American, reproductive, fell, Melinda,
# nearest to rights: businesss, Wagener, market, broad, perpetrators, 32, field, regard,
# nearest to is: was, has, minimize, are, be, play, facts, elect,
# nearest to when: .If, as, shouldnt, altitude, differences, prompting, where, for,
# nearest to should: can, would, will, may, must, tend, false, futures,
# nearest to with: basis, transcended, alienate, for, 1936, in, Denkinger, religion,
# nearest to own: swiftly, varieties, 2050, .Having, remittances, of, reach, hardly,
# nearest to was: is, were, are, C.I.A., be, pre-1967, has, trains,
# nearest to countries: rapprochement, .Castration, territorial, drugs, 1-2, tested, emergencies, helping,
# nearest to one: grief, board, profligate, Kelleher, inhabited, translate, powers, RAND,
# nearest to more: eliminated, Rey, decile, talent, less, referendums, reduce, Zamora,
# nearest to example: jail, miniature, contrast, smoking, helicopters, hare, carpenter, contributions,
# nearest to its: their, the, .Doubt, endorsement, secretary, severity, coming, themselves,
# nearest to make: attempted, constitute, did, all-time, Zoo, interpretation, ,Arming, audiences,
# nearest to no: Oslo, volunteering, a, .Kennedy, aimed, Cambodia, .China, Epps,
# nearest to any: a, 1995, restructuring, Jim, summoned, animals, measures, adapt,
# Average loss at step  22000 :  4.60245578563
# Average loss at step  24000 :  4.51002027464
# Average loss at step  26000 :  4.48361868632
# Average loss at step  28000 :  4.46305247462
# Average loss at step  30000 :  4.42238282287
# nearest to into: .Offshoring, al-Shabaab, stab, .American, reproductive, in, Melinda, fell,
# nearest to rights: businesss, Wagener, broad, market, perpetrators, field, regard, monopolize,
# nearest to is: was, has, minimize, are, be, elect, UAVs, play,
# nearest to when: .If, if, shouldnt, as, where, altitude, prompting, differences,
# nearest to should: can, would, will, must, may, tend, could, thirties,
# nearest to with: alienate, basis, 1936, transcended, .Tax, Denkinger, hunt, Cafardo,
# nearest to own: swiftly, varieties, sex-specific, reach, 2050, positively, Cafardo, remittances,
# nearest to was: is, were, has, be, are, inviolability, C.I.A., trains,
# nearest to countries: .Castration, rapprochement, emergencies, territorial, permits, drugs, helping, 1-2,
# nearest to one: grief, Kelleher, board, makeup, profligate, translate, inhabited, incurring,
# nearest to more: less, eliminated, Rey, Zamora, talent, referendums, .Horses, decile,
# nearest to example: miniature, jail, contrast, helicopters, hare, smoking, commuted, carpenter,
# nearest to its: their, the, .Doubt, secretary, coming, severity, endorsement, themselves,
# nearest to make: attempted, constitute, all-time, did, Zoo, slaughter, audiences, ,Arming,
# nearest to no: .Kennedy, Oslo, volunteering, Cambodia, passports, aimed, .China, Just,
# nearest to any: a, 1995, animals, restructuring, summoned, Jim, adapt, Jacques,
# Average loss at step  32000 :  4.39010683179
# Average loss at step  34000 :  4.37459684885
# Average loss at step  36000 :  4.35263361812
# Average loss at step  38000 :  4.33691542709
# Average loss at step  40000 :  4.30003402865
# nearest to into: al-Shabaab, .Offshoring, reproductive, stab, Melinda, .American, fell, cohabitation,
# nearest to rights: businesss, Wagener, perpetrators, broad, monopolize, regard, field, 77,
# nearest to is: was, has, minimize, elect, makes, UAVs, does, becomes,
# nearest to when: .If, if, shouldnt, altitude, where, prompting, case, pattern,
# nearest to should: can, must, will, would, may, tend, ovulation, could,
# nearest to with: transcended, alienate, 1936, basis, hunt, .Tax, Cafardo, Denkinger,
# nearest to own: swiftly, varieties, positively, .Short, sex-specific, Cafardo, 2050, remittances,
# nearest to was: is, were, has, be, trains, .Eritrea, inviolability, .1973,
# nearest to countries: .Castration, rapprochement, states, emergencies, permits, drugs, 2009US, helping,
# nearest to one: grief, makeup, Kelleher, board, profligate, incurring, connected, translate,
# nearest to more: less, eliminated, Rey, Zamora, talent, .Horses, referendums, decile,
# nearest to example: miniature, jail, contrast, helicopters, commuted, hare, smoking, everybody,
# nearest to its: their, .Doubt, secretary, the, coming, commuter, severity, multi-tracking,
# nearest to make: attempted, constitute, all-time, did, slaughter, interpretation, Zoo, ,Arming,
# nearest to no: .Kennedy, Cambodia, Oslo, volunteering, passports, little, .China, ,Unlike,
# nearest to any: a, restructuring, animals, 1995, Jacques, adapt, summoned, Jim,
# Average loss at step  42000 :  4.29988610768
# Average loss at step  44000 :  4.28599479973
# Average loss at step  46000 :  4.24153354037
# Average loss at step  48000 :  4.2398869772
# Average loss at step  50000 :  4.24088910007
# nearest to into: al-Shabaab, .Offshoring, reproductive, Melinda, stab, .American, Plus, insecure,
# nearest to rights: businesss, Wagener, broad, perpetrators, monopolize, field, regard, 77,
# nearest to is: was, has, minimize, UAVs, elect, worries, becomes, vouchers,
# nearest to when: if, .If, where, shouldnt, altitude, case, laissez-faire, prompting,
# nearest to should: must, will, can, would, may, could, tend, ovulation,
# nearest to with: 1936, alienate, hunt, tighter, transcended, .Tax, basis, Cafardo,
# nearest to own: positively, swiftly, varieties, .Short, sex-specific, Zambia, remittances, 2050,
# nearest to was: is, were, be, .Eritrea, has, trains, inviolability, pre-1967,
# nearest to countries: .Castration, states, rapprochement, emergencies, permits, attests, 2009US, drugs,
# nearest to one: grief, makeup, board, Kelleher, connected, profligate, composed, incurring,
# nearest to more: less, Zamora, Rey, talent, .Horses, under-develop, eliminated, reputable,
# nearest to example: miniature, contrast, jail, helicopters, commuted, hare, condone, everybody,
# nearest to its: their, the, .Doubt, secretary, commuter, coming, borders, severity,
# nearest to make: attempted, constitute, all-time, slaughter, produce, promote, keep, did,
# nearest to no: .Kennedy, Cambodia, little, Oslo, volunteering, passports, ,Unlike, .China,
# nearest to any: a, animals, restructuring, 1995, the, Jacques, adapt, second-generation,
# Average loss at step  52000 :  4.19406552327
# Average loss at step  54000 :  4.19121011686
# Average loss at step  56000 :  4.19840359151
# Average loss at step  58000 :  4.15406740284
# Average loss at step  60000 :  4.14309130418
# nearest to into: al-Shabaab, .Offshoring, reproductive, Melinda, Plus, stab, begged, insecure,
# nearest to rights: businesss, broad, Wagener, perpetrators, monopolize, regard, 77, Stunning,
# nearest to is: was, has, minimize, elect, UAVs, makes, vouchers, demonstrates,
# nearest to when: if, .If, laissez-faire, Ferdinand, shouldnt, arts, altitude, pattern,
# nearest to should: must, will, can, would, may, could, tend, ovulation,
# nearest to with: 1936, alienate, hunt, basis, transcended, tighter, Cafardo, .Tax,
# nearest to own: positively, .Short, sex-specific, varieties, swiftly, indoctrinate, Zambia, remittances,
# nearest to was: is, were, .Eritrea, trains, has, inviolability, be, Energy,
# nearest to countries: states, .Castration, rapprochement, emergencies, attests, permits, drugs, 2009US,
# nearest to one: makeup, grief, connected, Kelleher, composed, board, profligate, validity,
# nearest to more: less, Rey, Zamora, .Horses, talent, under-develop, .Debt, eliminated,
# nearest to example: miniature, contrast, jail, helicopters, commuted, condone, hare, everybody,
# nearest to its: their, .Doubt, secretary, the, commuter, fad, borders, Microsoft,
# nearest to make: attempted, constitute, all-time, produce, promote, keep, slaughter, interpreting,
# nearest to no: .Kennedy, Cambodia, little, passports, Oslo, volunteering, ,Unlike, .China,
# nearest to any: a, animals, restructuring, Jacques, 1995, second-generation, validity, the,
# Average loss at step  62000 :  4.16912408459
# Average loss at step  64000 :  4.1222755084
# Average loss at step  66000 :  4.09288251662
# Average loss at step  68000 :  4.1374227581
# Average loss at step  70000 :  4.08789818788
# nearest to into: al-Shabaab, .Offshoring, reproductive, Plus, begged, Melinda, stab, insecure,
# nearest to rights: businesss, perpetrators, broad, Wagener, monopolize, ran, 77, negatively,
# nearest to is: was, has, creates, demonstrates, elect, minimize, UAVs, does,
# nearest to when: if, .If, real-time, Ferdinand, shouldnt, job, laissez-faire, arts,
# nearest to should: must, will, would, can, may, tend, ovulation, could,
# nearest to with: 1936, hunt, tighter, alienate, Cafardo, transcended, .Tax, please,
# nearest to own: positively, .Short, indoctrinate, sex-specific, varieties, swiftly, Zambia, remittances,
# nearest to was: is, were, .Eritrea, be, trains, inviolability, Energy, has,
# nearest to countries: states, .Castration, rapprochement, attests, drugs, nations, 2009US, emergencies,
# nearest to one: connected, makeup, composed, grief, Kelleher, validity, 650, board,
# nearest to more: less, Rey, .Horses, talent, Zamora, under-develop, Goes, reputable,
# nearest to example: miniature, contrast, condone, jail, helicopters, commuted, hare, everybody,
# nearest to its: their, .Doubt, secretary, commuter, the, borders, fad, Microsoft,
# nearest to make: attempted, constitute, all-time, produce, keep, promote, slaughter, interpreting,
# nearest to no: .Kennedy, Cambodia, little, passports, Oslo, volunteering, ,Unlike, .Everyone,
# nearest to any: a, animals, restructuring, Jacques, 1995, validity, second-generation, library,
# Average loss at step  72000 :  4.05041494894
# Average loss at step  74000 :  4.1067070446
# Average loss at step  76000 :  4.0629480418
# Average loss at step  78000 :  4.01567695081
# Average loss at step  80000 :  4.07263186216
# nearest to into: al-Shabaab, .Offshoring, reproductive, Plus, begged, Melinda, insecure, cohabitation,
# nearest to rights: businesss, broad, perpetrators, Wagener, monopolize, negatively, ran, Stunning,
# nearest to is: was, has, demonstrates, minimize, creates, elect, becomes, makes,
# nearest to when: if, .If, real-time, job, ratios, Ferdinand, pattern, arts,
# nearest to should: must, will, would, can, may, tend, ovulation, could,
# nearest to with: 1936, alienate, hunt, Cafardo, tighter, .Tax, transcended, please,
# nearest to own: positively, indoctrinate, .Short, sex-specific, varieties, swiftly, Zambia, remittances,
# nearest to was: is, .Eritrea, were, inviolability, trains, Energy, be, has,
# nearest to countries: states, .Castration, nations, attests, rapprochement, emergencies, permits, drugs,
# nearest to one: composed, connected, makeup, validity, grief, .Education, pervade, 650,
# nearest to more: less, Rey, .Horses, Zamora, talent, Goes, guise, under-develop,
# nearest to example: contrast, miniature, condone, jail, helicopters, commuted, hare, endured,
# nearest to its: their, secretary, .Doubt, the, borders, fad, commuter, Microsoft,
# nearest to make: constitute, attempted, all-time, produce, keep, promote, organised, interpreting,
# nearest to no: .Kennedy, Cambodia, little, passports, Oslo, .Everyone, probably, volunteering,
# nearest to any: a, animals, restructuring, Jacques, validity, 1995, the, crowd,
# Average loss at step  82000 :  4.04584925938
# Average loss at step  84000 :  3.98581117594
# Average loss at step  86000 :  4.03016281164
# Average loss at step  88000 :  4.03227248263
# Average loss at step  90000 :  3.95713715684
# nearest to into: al-Shabaab, .Offshoring, reproductive, Plus, begged, Melinda, insecure, stab,
# nearest to rights: businesss, broad, perpetrators, monopolize, negatively, Wagener, absconding, ran,
# nearest to is: was, has, demonstrates, creates, seems, becomes, elect, makes,
# nearest to when: if, Ferdinand, real-time, job, ratios, laissez-faire, arts, .If,
# nearest to should: must, will, would, may, can, tend, ovulation, could,
# nearest to with: 1936, hunt, alienate, tighter, transcended, .Tax, please, Cafardo,
# nearest to own: positively, indoctrinate, .Short, sex-specific, varieties, swiftly, remittances, Zambia,
# nearest to was: is, .Eritrea, trains, were, inviolability, Energy, Kill, be,
# nearest to countries: states, .Castration, nations, rapprochement, attests, drugs, emergencies, 2009US,
# nearest to one: composed, connected, makeup, validity, pervade, grief, .Education, Kelleher,
# nearest to more: less, Rey, .Horses, Zamora, talent, Goes, under-develop, Protestants,
# nearest to example: contrast, condone, miniature, jail, helicopters, commuted, endured, hare,
# nearest to its: their, secretary, .Doubt, borders, fad, commuter, Microsoft, .Handguns,
# nearest to make: constitute, attempted, all-time, produce, keep, promote, organised, interpreting,
# nearest to no: little, .Kennedy, Cambodia, passports, .Everyone, Oslo, probably, Greece,
# nearest to any: animals, restructuring, a, Jacques, validity, flexibility, 1995, crowd,
# Average loss at step  92000 :  3.99528204036
# Average loss at step  94000 :  4.01730138969
# Average loss at step  96000 :  3.93130831909
# Average loss at step  98000 :  3.96137983572
# Average loss at step  100000 :  3.99481142795
# nearest to into: al-Shabaab, .Offshoring, Plus, reproductive, begged, insecure, Melinda, cohabitation,
# nearest to rights: businesss, broad, negatively, monopolize, perpetrators, absconding, ran, Wagener,
# nearest to is: was, has, demonstrates, creates, uninhibited, vouchers, denies, becomes,
# nearest to when: if, ratios, real-time, job, Ferdinand, laissez-faire, arts, earned,
# nearest to should: must, will, would, may, can, tend, ovulation, could,
# nearest to with: hunt, tighter, 1936, alienate, please, Cafardo, transcended, .Tax,
# nearest to own: positively, indoctrinate, .Short, sex-specific, remittances, varieties, Zambia, swiftly,
# nearest to was: is, .Eritrea, trains, Kill, were, Energy, inviolability, be,
# nearest to countries: states, nations, .Castration, attests, rapprochement, drugs, emergencies, 2009US,
# nearest to one: composed, connected, validity, makeup, pervade, .Education, grief, 650,
# nearest to more: less, Rey, Zamora, .Horses, under-develop, talent, Protestants, Goes,
# nearest to example: condone, contrast, miniature, commuted, helicopters, jail, endured, everybody,
# nearest to its: their, secretary, .Doubt, the, borders, fad, commuter, Microsoft,
# nearest to make: constitute, attempted, all-time, produce, keep, promote, organised, interpreting,
# nearest to no: little, .Kennedy, Cambodia, passports, .Everyone, Greece, Oslo, probably,
# nearest to any: animals, restructuring, a, validity, flexibility, the, Jacques, 1995,

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    # set plot size in inches
    plt.figure(figsize=(18, 18))
    # loop through all labels
    for i, label in enumerate(labels):
        # get the embedding vectors
        x, y = low_dim_embs[i, :]
        # plot them in a scatterplot
        plt.scatter(x, y)
        # annotations
        plt.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')

    # save the figure out
    plt.savefig(filename)

try:
    # import t-SNE and matplotlib.pyplot
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt
    
    # %matplotlib inline

    # create the t-SNE object with 2 components, PCA initialization, and 5000 iterations
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    # plot only so many words in the embedding
    plot_only = 500
    # fit the TSNE dimensionality reduction technique to the word vector embedding
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    # get the words associated with the points
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    # call the plotting function
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
